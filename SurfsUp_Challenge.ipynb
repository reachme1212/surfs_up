# %%
# Dependencies
import numpy as np
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import pandas as pd
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, MetaData, Table,func
import datetime as dt
from sqlalchemy import extract

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %%
inspector = inspect(engine)
columns = inspector.get_columns('measurement')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
inspector = inspect(engine)
columns = inspector.get_columns('station')
for column in columns:
    print(column["name"], column["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
#  3. Convert the June temperatures to a list.
# june_all_years_temps_list=[]
# june_all_years_temps_list = session.query(Measurement.date, Measurement.tobs)
# june_all_years_temps_list

# %%
# # 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June.
# 4. Create a DataFrame from the list of temperatures for the month of June. 

june_all_years_temps_list=[]
date_str = "06"
june_all_years_temps_list=session.query(Measurement.date,Measurement.prcp ,Measurement.tobs).\
    filter(func.strftime("%m", Measurement.date) == date_str,).all()
june_all_years_temps_list
# Out:
# [('2010-06-01', 0.0, 78.0),
#  ('2010-06-02', 0.01, 76.0),
#  ('2010-06-03', 0.0, 78.0),
#  ('2010-06-04', 0.0, 76.0),
#  ('2010-06-05', 0.0, 77.0),
#  ('2010-06-06', 0.0, 78.0),
#  ('2010-06-07', 0.0, 77.0),
#  ('2010-06-08', 0.0, 78.0),
#  ('2010-06-09', 0.0, 78.0),
#  ('2010-06-10', 0.0, 79.0),
#  ('2010-06-11', 0.0, 78.0),
#  ('2010-06-12', 0.0, 78.0),
#  ('2010-06-13', 0.0, 78.0),
#  ('2010-06-14', 0.0, 77.0),
#  ('2010-06-15', 0.0, 78.0),
#  ('2010-06-16', 0.0, 78.0),
#  ('2010-06-17', 0.0, 77.0),
#  ('2010-06-18', 0.0, 77.0),
#  ('2010-06-19', 0.0, 82.0),
#  ('2010-06-20', 0.0, 78.0),
#  ('2010-06-21', 0.0, 78.0),
#  ('2010-06-22', 0.0, 78.0),
#  ('2010-06-23', 0.0, 78.0),
#  ('2010-06-24', 0.0, 78.0),
#  ('2010-06-25', 0.0, 77.0),
#  ('2010-06-26', 0.02, 76.0),
#  ('2010-06-27', 0.0, 78.0),
#  ('2010-06-28', 0.0, 78.0),
#  ('2010-06-29', 0.0, 78.0),
#  ('2010-06-30', 0.0, 78.0),
#  ('2011-06-01', 0.07, 77.0),
#  ('2011-06-02', 0.0, 78.0),
#  ('2011-06-03', 0.56, 73.0),
# ...

# %%
len(june_all_years_temps_list)
# Out:
# 1700

# %%
june_all_years_temps_df = pd.DataFrame(june_all_years_temps_list,columns=['Dates','Prcp','Tobs'] )
june_all_years_temps_df.head()
# Out:
#         Dates  Prcp  Tobs
# 0  2010-06-01  0.00  78.0
# 1  2010-06-02  0.01  76.0
# 2  2010-06-03  0.00  78.0
# 3  2010-06-04  0.00  76.0
# 4  2010-06-05  0.00  77.0

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_all_years_temps_df.describe()
# Out:
#               Prcp         Tobs
# count  1574.000000  1700.000000
# mean      0.136360    74.944118
# std       0.335731     3.257417
# min       0.000000    64.000000
# 25%       0.000000    73.000000
# 50%       0.020000    75.000000
# 75%       0.120000    77.000000
# max       4.430000    85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
# 7. Convert the December temperatures to a list.
dec_all_years_temps_list=[]
date_str = "12"
dec_all_years_temps_list=session.query(Measurement.date,Measurement.prcp ,Measurement.tobs).\
    filter(func.strftime("%m", Measurement.date) == date_str).all()
dec_all_years_temps_list
# Out:
# [('2010-12-01', 0.04, 76.0),
#  ('2010-12-03', 0.0, 74.0),
#  ('2010-12-04', 0.0, 74.0),
#  ('2010-12-06', 0.0, 64.0),
#  ('2010-12-07', 0.0, 64.0),
#  ('2010-12-08', 0.0, 67.0),
#  ('2010-12-09', 0.0, 77.0),
#  ('2010-12-10', 1.58, 66.0),
#  ('2010-12-11', 0.77, 69.0),
#  ('2010-12-12', 0.0, 68.0),
#  ('2010-12-13', 0.0, 68.0),
#  ('2010-12-14', 0.0, 71.0),
#  ('2010-12-15', 0.0, 74.0),
#  ('2010-12-16', 0.0, 67.0),
#  ('2010-12-17', 0.0, 66.0),
#  ('2010-12-18', 0.0, 69.0),
#  ('2010-12-19', 1.4, 71.0),
#  ('2010-12-23', 0.0, 70.0),
#  ('2010-12-24', 0.0, 70.0),
#  ('2010-12-26', None, 74.0),
#  ('2010-12-27', 0.13, 74.0),
#  ('2010-12-28', 0.55, 71.0),
#  ('2010-12-29', 0.06, 75.0),
#  ('2010-12-30', 0.01, 75.0),
#  ('2010-12-31', 0.0, 72.0),
#  ('2011-12-01', 0.03, 69.0),
#  ('2011-12-02', 0.08, 68.0),
#  ('2011-12-03', 0.0, 73.0),
#  ('2011-12-04', 0.0, 74.0),
#  ('2011-12-05', 0.0, 73.0),
#  ('2011-12-06', 0.0, 73.0),
#  ('2011-12-07', 0.0, 73.0),
#  ('2011-12-08', 0.0, 73.0),
# ...

# %%
len(dec_all_years_temps_list)
# Out:
# 1517

# %%
dec_all_years_temps_df = pd.DataFrame(dec_all_years_temps_list,columns=['Dates','Prcp','Tobs'] )
dec_all_years_temps_df.head()
# Out:
#         Dates  Prcp  Tobs
# 0  2010-12-01  0.04  76.0
# 1  2010-12-03  0.00  74.0
# 2  2010-12-04  0.00  74.0
# 3  2010-12-06  0.00  64.0
# 4  2010-12-07  0.00  64.0

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_all_years_temps_df.describe()
# Out:
#               Prcp         Tobs
# count  1405.000000  1517.000000
# mean      0.216819    71.041529
# std       0.541399     3.745920
# min       0.000000    56.000000
# 25%       0.000000    69.000000
# 50%       0.030000    71.000000
# 75%       0.150000    74.000000
# max       6.420000    83.000000

# %%
#total dates in given data 
dates_count=session.query(func.count(Measurement.date)).all()
dates_count
# Out:
# [(19550,)]

# %%
# Earliest Date on the data 
session.query(Measurement.date).order_by(Measurement.date).first()
# Out:
# ('2010-01-01',)

# %%
# Latest Date on the data 
session.query(Measurement.date).order_by(Measurement.date.desc()).first()
# Out:
# ('2017-08-23',)

# %%
#total number of station in data
total_stations=session.query(Measurement.station, func.count(Measurement.station)).\
group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
total_stations
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# we will use the stations which have most data first 3 
# USC00519281 , USC00519397,USC00513117
# min ,max and avg tempratures for these  stations 

station_1= session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00519281').all()

station_1
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
station_2= session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00519397').all()

station_2
# Out:
# [(56.0, 87.0, 74.55323054331865)]

# %%
station_3= session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
filter(Measurement.station == 'USC00513117').all()

station_3
# Out:
# [(59.0, 85.0, 72.68918420081211)]

# %%
station_1_allyear = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.date.between('2015-01-01','2017-12-31')).filter(Measurement.station == 'USC00519281').all()
station_1_allyear
# Out:
# [(56.0, 85.0, 72.41850683491062)]

# %%
station_2_allyear = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.date.between('2015-01-01','2017-12-31')).filter(Measurement.station == 'USC00519397').all()

station_2_allyear
# Out:
# [(58.0, 87.0, 74.90833333333333)]

# %%
station_3_allyear = session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.date.between('2015-01-01','2017-12-31')).filter(Measurement.station == 'USC00513117').all()

station_3_allyear
# Out:
# [(60.0, 85.0, 73.29868708971554)]

# %%
june_all_years_temps_df.head()
# Out:
#         Dates  Prcp  Tobs
# 0  2010-06-01  0.00  78.0
# 1  2010-06-02  0.01  76.0
# 2  2010-06-03  0.00  78.0
# 3  2010-06-04  0.00  76.0
# 4  2010-06-05  0.00  77.0

# %%
# Due to climate change i feel we need to take the weather data of recent year for the june and december  
# so filtered those years from june data 2015 ,2016 and 2017
June_recent_df=june_all_years_temps_df[(june_all_years_temps_df["Dates"] >= '2015-01-01') & (june_all_years_temps_df["Dates"] <= '2017-12-31')]
June_recent_df
# Out:
#            Dates  Prcp  Tobs
# 146   2015-06-01  0.00  78.0
# 147   2015-06-02  0.00  78.0
# 148   2015-06-03  0.00  79.0
# 149   2015-06-04  0.00  77.0
# 150   2015-06-05  0.00  79.0
# ...          ...   ...   ...
# 1695  2017-06-26  0.02  79.0
# 1696  2017-06-27  0.10  74.0
# 1697  2017-06-28  0.02  74.0
# 1698  2017-06-29  0.04  76.0
# 1699  2017-06-30  0.20  75.0
#
# [588 rows x 3 columns]

# %%
June_recent_df.describe()
# Out:
#              Prcp        Tobs
# count  532.000000  588.000000
# mean     0.151842   75.775510
# std      0.288793    3.392136
# min      0.000000   64.000000
# 25%      0.000000   73.750000
# 50%      0.030000   76.000000
# 75%      0.170000   78.000000
# max      2.470000   83.000000

# %%
Dec_recent_df=dec_all_years_temps_df[(dec_all_years_temps_df["Dates"] >= '2015-01-01') & (dec_all_years_temps_df["Dates"] <= '2017-12-31')]
Dec_recent_df
# Out:
#            Dates  Prcp  Tobs
# 148   2015-12-01  0.00  75.0
# 149   2015-12-02  0.00  77.0
# 150   2015-12-03  0.06  75.0
# 151   2015-12-04  0.02  75.0
# 152   2015-12-05  0.00  75.0
# ...          ...   ...   ...
# 1512  2016-12-27  0.14  71.0
# 1513  2016-12-28  0.14  71.0
# 1514  2016-12-29  1.03  69.0
# 1515  2016-12-30  2.37  65.0
# 1516  2016-12-31  0.90  65.0
#
# [384 rows x 3 columns]

# %%
Dec_recent_df.describe()
# Out:
#              Prcp        Tobs
# count  340.000000  384.000000
# mean     0.185206   72.229167
# std      0.318720    3.467052
# min      0.000000   60.000000
# 25%      0.020000   70.000000
# 50%      0.060000   72.000000
# 75%      0.212500   75.000000
# max      2.370000   82.000000
